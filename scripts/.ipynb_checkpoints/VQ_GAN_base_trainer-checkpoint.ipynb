# %%
#!pip install pydub
#!pip install torchaudio==0.7.0
#!pip install librosa==0.8.0
#!pip install torch-audiomentations
#!pip install tensorboard
#!tensorboard --logdir=runs

#!pip install torchaudio
#!pip install torch==1.6.0+cu101 torchvision==0.7.0+cu101 torchaudio==0.6.0 -f https://download.pytorch.org/whl/torch_stable.html
#!pip install torch

# %%
os.chdir('C:/Users/pedro/Documents/git/VQ_GAN_music')

# %%
import os
import sys
import time
import glob
import json
import random
import math
import datetime
import pickle
from collections import defaultdict

# %%
sys.path.append('..')

# %%
import yaml
 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#from scipy.io import wavfile

import torch
import torchaudio
#torchaudio.set_audio_backend("sox_io")
import torch.nn as nn
import torch.nn.functional as F
from torch.cuda.amp import GradScaler
from torch.utils.tensorboard import SummaryWriter

#import torch_audiomentations
 
#import librosa
#import librosa.display
import IPython.display as ipd

from VQ_GAN_music.models.vq_vae.vq_vae import VQVAE
from VQ_GAN_music.models.discriminator import MultiDiscriminator
from VQ_GAN_music.models.losses import hinge_loss, vq_vae_loss
from VQ_GAN_music.utils.vq_vae_trainer import VQVAETrainer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-38a97f4f0411> in <module>
#      20 import IPython.display as ipd
#      21
# ---> 22 from VQ_GAN_music.models.vq_vae.vq_vae import VQVAE
#      23 from VQ_GAN_music.models.discriminator import MultiDiscriminator
#      24 from VQ_GAN_music.models.losses import hinge_loss, vq_vae_loss
#
# ~\Documents\git\VQ_GAN_music\models\vq_vae\vq_vae.py in <module>
#       1 import torch
#       2 import torch.nn as nn
# ----> 3 from modules import VQVAEEncoder, VQVAEDecoder, VectorQuantizer
#       4
#       5
#
# ModuleNotFoundError: No module named 'modules'

# %%
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Out:
# ['VQ_GAN-music.ipynb', 'VQ_GAN_base_trainer.ipynb', 'VQ_GAN_trainer.ipynb']

# %%
print(torch.version.cuda)
# Out:
# None

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
torch.cuda.is_available()
# Out:
# False

# %%
# !nvidia-smi
# Out:
# Wed Mar 31 13:35:09 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 445.75       Driver Version: 445.75       CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce 940M       WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   45C    P8    N/A /  N/A |     37MiB /  2048MiB |      1%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# ...

# %%
# os.mkdir('Medley-solos-DB')
#zip_path = '/content/drive/MyDrive/IRMAS-TrainingData/IRMAS-TrainingData.zip'
#zip_path = '/content/drive/MyDrive/IRMAS-TrainingData/IRMAS-TrainingData.zip'
#!cp "{zip_path}" .
#!unzip -q IRMAS-TrainingData.zip
#!rm IRMAS-TrainingData.zip

# %% [markdown]
# ## Dataset

# %%
fma_dir ='C:/Users/pedro/Google Drive (p185770@dac.unicamp.br)/fma_small'
#fma_dir = '/content/drive/My Drive/fma_small/fma_small/*/*.mp3'
#fma_val_dir = '/content/drive/My Drive/fma_small/fma_small/029/*.mp3'

# %%
with open(r'C:/Users/pedro/Documents/git/VQ_GAN_music/config/fma.yaml') as file:
    hps = yaml.full_load(file)

# %%
SAMPLE_RATE = 22050
WINDOW_SIZE = int(2**(np.ceil(np.log2(SAMPLE_RATE*4)))) # aprox 4 segundos
HOP_LEN = int(2**(np.ceil(np.log2(SAMPLE_RATE*4))))
QUANTIZATION_CHANNELS = 256

VQVAE_BATCH_SIZE = 1
VQVAE_BUFFER_SIZE = 20000

# %%
# Hiperparâmetros
LATENT_K = 512# número de entradas do codebook
LATENT_D = 64 # dimensão das entradas do codebook

BETA = 0.25 # peso para a commitment loss

INPUT_SHAPE = [1, 80000]
SIZE = None # tamanho espacial dos embeddings latentes(configurado dimamicamente)

VQVAE_NUM_EPOCHS = 20
VQVAE_LEARNING_RATE = 3e-4

VQVAE_FILTERS = [64, 64, 64, 64, 64] # número de filtros para as camadas do encoder

CONT = 2**(len(VQVAE_FILTERS))


#Sample rates convertidos
RATE = SAMPLE_RATE/(2**(len(VQVAE_FILTERS)))

# %% [markdown]
# ### Dataset

# %%
music_dataset = MusicDataset(fma_dir, SAMPLE_RATE, WINDOW_SIZE, HOP_LEN, 2)

# %%
music_dataloader = torch.utils.data.DataLoader(music_dataset, batch_size=None, num_workers=3)

# %%
next(iter(music_dataloader))
# Out:
# {'annotations': tensor([[[0.3000, 0.6000]],
#
#          [[0.3000, 0.6000]]]), 'ids': tensor([[170.],
#          [170.]]), 'inputs': tensor([[[ 0.0078,  0.0078,  0.0078,  ...,  0.7656,  0.7734,  0.7891]],
#
#          [[ 0.8047,  0.8203,  0.8359,  ...,  0.6484, -0.3750, -0.6484]]]), 'targets': tensor([[[ 0.0078,  0.0078,  0.0078,  ...,  0.7656,  0.7734,  0.7891]],
#
#          [[ 0.8047,  0.8203,  0.8359,  ...,  0.6484, -0.3750, -0.6484]]])}

# %%
next(iter(music_dataloader))['inputs'].shape
# Out:
# torch.Size([2, 1, 131072])

# %%
data_test = next(iter(music_dataloader))
ipd.Audio(data_test['inputs'][0], rate = SAMPLE_RATE)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(data_test['targets'][0], rate = SAMPLE_RATE)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## VQ_VAE

# %% [markdown]
# ### Models

# %%
encoder = Encoder(2, TOP_VQVAE_FILTERS, BOTTOM_VQVAE_FILTERS, 6, WINDOW_SIZE).to(device)
generator = Generator(LATENT_D, LATENT_K, 1, TOP_VQVAE_FILTERS, BOTTOM_VQVAE_FILTERS, 6, WINDOW_SIZE, TOP_CONT, BOTTOM_CONT).to(device)
discriminator = Discriminator(1, 32, [32,32,32,32], [16, 16, 8, 4, 2, 1], 4).to(device)

# %%
encoder.load_state_dict(torch.load(checkpoint_dir + 'encoder_state.bin'))
generator.load_state_dict(torch.load(checkpoint_dir + 'generator_state.bin'))
# Out:
# <All keys matched successfully>

# %%
encoder.to(device)
generator.to(device)
discriminator.to(device);

# %% [markdown]
# ### GAN Trainer

# %%
gan_trainer = GANTrainer(encoder, generator, discriminator, None, music_dataloader, [mse_loss, latent_loss, latent_loss, bce_loss], device, 1e-3, 1e-3, 1e-3, 1, [LATENT_D, 1250,  5000])

# %%
samples = gan_trainer.train(1, checkpoint_dir, train_gan=False)
# Out:
# Epoch 1/1
# ----------
# |     1 batches | lr 2.0000000 | ms/batch 2328.24 | loss 0.57276 | loss_list: [0.3894102  0.06379911 0.06937928 0.0501759 ]
# |     2 batches | lr 2.0000000 | ms/batch 1526.36 | loss 0.58712 | loss_list: [0.39977717 0.05052613 0.07913481 0.05767864]
# |     3 batches | lr 2.0000000 | ms/batch 1527.92 | loss 0.64427 | loss_list: [0.4230008  0.0728414  0.08428341 0.06414572]
# |     4 batches | lr 2.0000000 | ms/batch 1526.77 | loss 0.63131 | loss_list: [0.41843177 0.05604674 0.0898616  0.06697014]
# |     5 batches | lr 2.0000000 | ms/batch 1526.23 | loss 0.64424 | loss_list: [0.43040779 0.05224052 0.09302753 0.0685675 ]
# |     6 batches | lr 2.0000000 | ms/batch 1524.04 | loss 0.67058 | loss_list: [0.44418098 0.0623509  0.09517232 0.06887417]
# |     7 batches | lr 2.0000000 | ms/batch 1528.59 | loss 0.66625 | loss_list: [0.44828134 0.05437837 0.0964002  0.06719317]
# ...
